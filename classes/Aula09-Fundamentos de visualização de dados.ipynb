# %% [markdown]
# ![aula09capa.png](attachment:aula09capa.png)

# %% [markdown]
# ### 0. Importando as bibliotecas necessárias

# %%
pip install plotly

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %% [markdown]
# ### 1. Introdução aos Princípios do Design de Visualizações
#
# Visualizações são ferramentas poderosas para comunicar informações de forma clara e eficaz. Esta seção aborda os princípios de design de visualizações com exemplos de boas e más práticas, baseados em:
#
# - Clareza
# - Simplicidade
# - Uso de Cores
#
# Além disso, destacaremos a importância de compreender o público-alvo e o contexto em que a visualização será utilizada.

# %% [markdown]
# ### 1.1 Clareza
#
# Visualizações claras permitem que os usuários entendam as informações rapidamente, sem ambiguidades. Evite sobrecarregar os gráficos com elementos desnecessários.

# %% [markdown]
# - Exemplo de má prática: Gráfico confuso

# %%
# Dados para o gráfico
np.random.seed(10)
data = np.random.rand(10, 4)
categorias = ['A', 'B', 'C', 'D']

# Má prática: Gráfico confuso com excesso de elementos
plt.figure(figsize=(8, 6))
for i, col in enumerate(categorias):
    plt.plot(data[:, i], label=f"Categoria {col}")
plt.title("Exemplo de Gráfico Confuso")
plt.legend()
plt.show()

# %% [markdown]
# - Exemplo de má prática: Gráfico confuso
#
# O primeiro exemplo demonstra um gráfico confuso devido a diversos problemas:
#
# 1. **Excesso de Linhas**: O uso de múltiplas linhas sobrepostas dificulta a identificação de padrões claros entre as categorias.
# 2. **Falta de Destaque**: Não há distinção suficiente entre os dados mais importantes e os elementos complementares.
# 3. **Legendas Exageradas**: O uso de uma legenda com muitas categorias sobrecarrega o leitor, tornando mais difícil identificar as linhas correspondentes.
#
# Esses problemas podem levar à sobrecarga cognitiva, fazendo com que o público tenha dificuldade em interpretar as informações apresentadas.
#
# ---

# %% [markdown]
# - Exemplo de boa prática: Gráfico claro

# %%
# Boa prática: Gráfico claro
plt.figure(figsize=(8, 6))
valoresMedios = data.mean(axis=0)
plt.bar(categorias, valoresMedios, color=['blue', 'orange', 'green', 'red'])
plt.title("Exemplo de Gráfico Claro")
plt.ylabel("Valores Médios")
plt.xlabel("Categorias")
plt.show()

# %% [markdown]
# - Exemplo de boa prática: Gráfico claro
#
# No segundo exemplo, o gráfico é claro e eficaz pelos seguintes motivos:
#
# 1. **Simplicidade**: O gráfico apresenta apenas os valores médios das categorias, removendo informações redundantes ou desnecessárias.
# 2. **Uso de Barras**: As barras são mais adequadas para comparar valores entre categorias, tornando as diferenças mais visuais e óbvias.
# 3. **Cores Distintas**: As cores escolhidas ajudam a distinguir as categorias sem causar confusão ou distração.
# 4. **Elementos Relevantes**: Apenas os elementos essenciais, como título, eixos e barras, são exibidos, facilitando a compreensão do público.
#
# Este gráfico prioriza a comunicação eficiente, garantindo que as informações sejam transmitidas de forma rápida e precisa.

# %% [markdown]
# ---

# %% [markdown]
# ### 1.2 Simplicidade
# Gráficos simples são mais fáceis de interpretar. Remova elementos visuais desnecessários, como grades excessivas e legendas redundantes.

# %% [markdown]
# - Exemplo de má prática: Gráfico sobrecarregado

# %%
# Dados para o gráfico
x = np.arange(1, 6)
y = [5, 7, 3, 8, 6]

# Má prática: Gráfico com excesso de informações
plt.figure(figsize=(8, 6))
plt.plot(x, y, label="Dados", marker='o', linestyle='--', color='purple')
plt.grid(which='both', color='red', linestyle='--', linewidth=1)
plt.legend(loc='upper right')
plt.title("Gráfico com Excesso de Informações")
plt.xlabel("Eixo X")
plt.ylabel("Eixo Y")
plt.show()

# %% [markdown]
# - Exemplo de má prática: Gráfico sobrecarregado
#
# O primeiro exemplo apresenta um gráfico com excesso de elementos visuais desnecessários:
#
# 1. **Estilo Exagerado**: A combinação de linhas pontilhadas, marcadores e múltiplas cores adiciona complexidade sem contribuir para a compreensão dos dados.
# 2. **Excesso de Grades**: A presença de grades em todos os níveis visuais desvia a atenção dos dados principais.
# 3. **Legenda Supérflua**: Uma única série de dados foi rotulada na legenda, o que não é necessário neste caso, pois as informações podem ser deduzidas diretamente a partir do título e dos eixos.
#
# Esses elementos extras poluem o design do gráfico, tornando-o visualmente pesado e dificultando a leitura para o público.

# %% [markdown]
# - Exemplo de boa prática: Gráfico simples

# %%
# Boa prática: Gráfico simples
plt.figure(figsize=(8, 6))
plt.plot(x, y, marker='o', color='blue')
plt.title("Gráfico Simples")
plt.xlabel("Eixo X")
plt.ylabel("Eixo Y")
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# ### 1.3 Uso de Cores
# As cores devem ser usadas com propósito e moderação. Escolha paletas que sejam acessíveis para pessoas com daltonismo e evite combinações que confundam o leitor.

# %% [markdown]
# - Exemplo de má prática: Uso inadequado de cores

# %%
# Má prática: Uso inadequado de cores
categorias = ['Categoria A', 'Categoria B', 'Categoria C', 'Categoria D']
valores = [15, 25, 30, 10]

plt.figure(figsize=(8, 6))
plt.bar(categorias, valores, color=['red', 'green', 'blue', 'yellow'])
plt.title("Gráfico com Cores Confusas")
plt.xlabel("Categorias")
plt.ylabel("Valores")
plt.show()

# %% [markdown]
# - O primeiro exemplo apresenta problemas significativos relacionados ao uso de cores:
#
# 1. **Combinações Distrativas**: O uso de cores como vermelho, verde, azul e amarelo cria uma combinação visualmente confusa e potencialmente problemática para pessoas com daltonismo.
# 2. **Falta de Propósito**: As cores não seguem uma lógica ou um esquema claro, tornando difícil entender se há alguma relação entre as categorias representadas.
# 3. **Estética Comprometida**: A escolha de cores saturadas e não harmoniosas dá ao gráfico uma aparência amadora, reduzindo sua eficácia em ambientes profissionais.
#
# Essas escolhas comprometem a legibilidade e tornam a interpretação do gráfico mais difícil, especialmente para públicos diversos.

# %%
# Boa prática: Uso apropriado de cores
plt.figure(figsize=(8, 6))
sns.barplot(x=categorias, y=valores, palette="viridis")
plt.title("Gráfico com Cores Apropriadas")
plt.ylabel("Valores")
plt.xlabel("Categorias")
plt.show()

# %% [markdown]
# No segundo exemplo, as cores são utilizadas de forma eficaz e intencional:
#
# 1. **Paleta Harmoniosa**: O uso de uma paleta consistente e visualmente agradável (como a "viridis") cria uma experiência visual mais fluida e acessível.
# 2. **Clareza e Contraste**: As cores escolhidas oferecem contraste suficiente para diferenciar as categorias sem causar distração.
# 3. **Inclusividade**: A paleta foi projetada para ser acessível a pessoas com daltonismo, garantindo que todos os públicos possam interpretar o gráfico adequadamente.
#
# Este gráfico demonstra como o uso estratégico de cores pode melhorar a clareza, a estética e a acessibilidade, tornando a visualização mais eficiente e inclusiva para todos os públicos.

# %% [markdown]
# ---

# %% [markdown]
# ### 1.4 Público-Alvo e Contexto
# É essencial compreender quem verá sua visualização e em que contexto ela será usada. Por exemplo:
#
# - Um público técnico pode preferir gráficos mais detalhados.
# - Um público geral pode precisar de gráficos mais simplificados.
#
# Sempre ajuste seu design com base no objetivo da visualização.

# %% [markdown]
# - Público técnico: Scatter plot detalhado

# %%
x = np.linspace(0, 10, 100)
y = np.sin(x) + np.random.normal(0, 0.1, size=x.shape)

plt.figure(figsize=(8, 6))
plt.scatter(x, y, alpha=0.7, edgecolors='k')
plt.title("Visualização para Público Técnico")
plt.xlabel("X")
plt.ylabel("Y")
plt.show()

# %% [markdown]
# - Público geral: Linha suavizada

# %%
plt.figure(figsize=(8, 6))
sns.lineplot(x=x, y=np.sin(x), color='blue', alpha=0.4)
plt.title("Visualização para Público Geral")
plt.xlabel("X")
plt.ylabel("Y")
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# ### 1.5 Interatividade
# Você pode usar esses gráficos para explorar dados ou tornar relatórios mais impactantes.

# %% [markdown]
# - Gráfico de Barras Interativo

# %%
pip show plotly

# %%
import plotly.graph_objects as go
# import plotly.express as px
import plotly.express as px

# Dados para o gráfico
categorias = ['Categoria A', 'Categoria B', 'Categoria C', 'Categoria D']
valores = [15, 25, 30, 10]

# Criar o gráfico de barras
fig = go.Figure(data=[
    go.Bar(x=categorias, y=valores, text=valores, textposition='auto', marker=dict(color=px.colors.qualitative.Pastel))
])

# Exibir o gráfico
fig.show()

# %%
# Personalização
fig.update_layout(
    title="Gráfico de Barras Interativo",
    xaxis_title="Categorias",
    yaxis_title="Valores",
    template="plotly_white",
    xaxis=dict(
        showgrid=True,        
        gridcolor="lightgrey"  
    ),
    yaxis=dict(
        showgrid=True,        
        gridcolor="lightgrey"  
    )
)
fig.show()

# %% [markdown]
# - Gráfico de dispersão interativo

# %%
import plotly.express as px
import pandas as pd

# Dados para o gráfico
df = pd.DataFrame({
    "Ano": [2020, 2021, 2022, 2023, 2024],
    "Categoria": ['A', 'B', 'C', 'D', 'E'],
    "Valor": [10, 20, 30, 40, 50]
})

# Criar o gráfico de dispersão
fig = px.scatter(
    df,
    x="Ano",
    y="Valor",
    size="Valor",
    color="Categoria",
    title="Gráfico de Dispersão com Slider",
    animation_frame="Ano",
    range_x=[2019, 2025],
    range_y=[0, 60]
)

# Exibir o gráfico
fig.show()

# %%
# Criando o dataset
data = {
    'Data': pd.date_range(start='2024-01-01', periods=120, freq='D'),
    'Categoria': ['Laptop', 'Tablet', 'Smartphone'] * 40,
    'Regiao': ['Norte', 'Sul', 'Nordeste', 'Sudeste'] * 30,
    'Vendas': [round(x, 2) for x in abs(1000 * pd.Series(np.random.randn(120)))],
    'Receita': [round(x, 2) for x in abs(5000 * pd.Series(np.random.randn(120)))]
}
df = pd.DataFrame(data)

# %% [markdown]
# - Gráfico de pizza interativo

# %%
# Gráfico de pizza com proporção de vendas por região
fig = px.pie(df, names='Regiao', values='Vendas', title='Proporção de Vendas por Região')
fig.show()

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ### 1.6 Conclusão
#
# A criação de visualizações eficazes exige a aplicação de princípios fundamentais como clareza, simplicidade e uso consciente de cores. Compreender o público-alvo e o contexto garante que as visualizações sejam úteis e impactantes.

# %% [markdown]
# ---

# %% [markdown]
# ### 2. DashBoards

# %% [markdown]
# ### Conceito
# Um ``dashboard`` é uma ferramenta visual que apresenta informações, dados e métricas de forma consolidada e interativa.
# Ele funciona como um "painel de controle", permitindo que os usuários monitorem indicadores-chave de desempenho (Key Performance Indicator- KPIs) e
# tomem decisões com base em dados em tempo real.
#
# Dashboards são amplamente utilizados em diversas áreas devido à sua capacidade de traduzir dados complexos em visualizações intuitivas, como gráficos, tabelas e mapas. Isso facilita a interpretação de tendências, padrões e insights importantes.
#
# ---
#
# ### Por que Dashboards são importantes?
# Dashboards são fundamentais para:
# - ``Monitoramento em tempo real:`` Permitem visualizar o desempenho de processos, vendas ou outros indicadores à medida que os dados são gerados.
# - ``Tomada de decisão:`` Apresentam informações claras e objetivas para suportar decisões estratégicas.
# - ``Comunicação de dados:`` Facilitam o compartilhamento de resultados com equipes e stakeholders de forma visualmente atraente.
# - ``Eficiência operacional:`` Centralizam informações relevantes em um único local, reduzindo o tempo gasto na busca e interpretação de dados.
#
# ---
#
# ### Exemplos Práticos de Uso
# 1. Empresas monitorando vendas:
#    - Acompanhamento de vendas diárias, mensais e anuais.
#    - Identificação de produtos ou regiões com melhor desempenho.
#    - Comparação de receitas e custos para avaliar a lucratividade.
#
# 2. Análise financeira:
#    - Controle de despesas e receitas em tempo real.
#    - Identificação de tendências financeiras, como aumentos ou quedas em receitas.
#    - Projeções de fluxo de caixa e lucros.
#
# 3. Controle de operações:
#    - Monitoramento de estoques em tempo real.
#    - Análise de tempo de entrega de pedidos.
#    - Detecção de gargalos em processos operacionais.
#
# ---

# %% [markdown]
# ### 2.1 Ferramentas para geração de Dashboards
# Abaixo, destacamos algumas das principais ferramentas de geração de dashboards:

# %% [markdown]
# - **Power BI**
#
# Descrição: Desenvolvida pela Microsoft, é uma das ferramentas mais populares para criação de dashboards interativos. Oferece uma ampla integração com outros produtos da Microsoft, como Excel e Azure.

# %% [markdown]
# **Vantagens**:
#
# - Interface amigável para usuários iniciantes.
# - Grande variedade de conectores de dados.
# - Recursos avançados de análise e visualização.
#
# Ideal para: Empresas que já utilizam produtos da Microsoft e buscam relatórios personalizados.
#
# Donwload em: https://www.microsoft.com/pt-br/download/details.aspx?id=58494

# %% [markdown]
# ### Vamos apresentar a ferramenta Power Bi

# %% [markdown]
# Dataset para exemplo : https://archive.ics.uci.edu/dataset/352/online+retail

# %% [markdown]
# # Online Retail Dataset
#
# ## Descrição Geral
# O dataset "Online Retail" contém transações ocorridas entre 01/12/2010 e 09/12/2011 de uma empresa online do Reino Unido que vende "gifts" (presentes) para clientes corporativos e varejistas.
#
# ## Fonte
# O dataset está disponível no repositório da UCI Machine Learning Repository: [Online Retail Dataset](https://archive.ics.uci.edu/dataset/352/online+retail)
#
# ## Informações sobre as Colunas
# As características do dataset são descritas a seguir:
#
# | Coluna              | Tipo de Dado | Descrição                                                                                     |
# |---------------------|--------------|-----------------------------------------------------------------------------------------------|
# | **InvoiceNo**       | `String`     | Número único identificador da fatura. Se começar com "C", indica um cancelamento de transação.|
# | **StockCode**       | `String`     | Código único identificador do item (produto).                                                |
# | **Description**     | `String`     | Descrição do item.                                                                           |
# | **Quantity**        | `Integer`    | Quantidade do produto vendido (pode ser negativa em caso de devolução).                      |
# | **InvoiceDate**     | `DateTime`   | Data e hora da transação.                                                                    |
# | **UnitPrice**       | `Float`      | Preço unitário do produto (em libras esterlinas).                                            |
# | **CustomerID**      | `String`     | Identificador único do cliente. Pode ser nulo em transações desconhecidas.                   |
# | **Country**         | `String`     | Nome do país onde o cliente está localizado.                                                |
#
# ## Tamanho do Dataset
# - **Número de Linhas:** 541.909
# - **Número de Colunas:** 8
#
# ## Observações Importantes
# 1. Algumas transações podem ter valores negativos na coluna **Quantity**, indicando devoluções.
# 2. Valores nulos estão presentes na coluna **CustomerID**, pois nem todas as transações estão vinculadas a um cliente identificado.
# 3. A coluna **Country** identifica o país de origem do cliente. A maioria das transações são do Reino Unido.
#
# ## Aplicações Comuns
# O dataset é frequentemente utilizado para:
# - **Análise de Vendas**: Identificar padrões de consumo, sazonalidade e produtos mais vendidos.
# - **Customer Segmentation**: Agrupamento de clientes com base no comportamento de compra.
# - **Análise de Churn**: Identificar clientes que estão deixando de realizar compras.
# - **Modelagem de RFM (Recência, Frequência e Valor Monetário)**: Para segmentação e personalização de campanhas.

# %%
pip install openpyxl

# %%
import pandas as pd

# Caminho do arquivo do dataset (ajuste conforme necessário)
file_path = '../classes/datasets/Online Retail.xlsx'

# Leitura do dataset
df = pd.read_excel(file_path)

# Exibir as primeiras linhas do DataFrame
print(df.head())

# Informações gerais sobre o DataFrame
print(df.info())

# %% [markdown]
# ### - Tranformar dados no POWER BI

# %% [markdown]
# **Limpeza básica de dados:**
# - Remova colunas desnecessárias (se houver).
# - Trate valores nulos (especialmente em CustomerID).
# - Altere tipos de dados (por exemplo, InvoiceDate para Data/Hora).
# - Filtre registros com quantidades negativas ou valores fora do esperado, caso necessário.

# %% [markdown]
# ### - Criar Visualizações no POWER BI

# %% [markdown]
# **Dashboard Resumo:**
#
# - Crie um Cartão para exibir o número total de transações. Colunas: InvoiceNo
# - Adicione Gráficos de Colunas ou Pizza para mostrar os 10 produtos mais vendidos. Colunas: Description e Quantity
# - Inclua um Gráfico de Barras para vendas por país. Colunas : Country e Quantity
# - Insira um Gráfico de Linha para visualizar vendas ao longo do tempo. Colunas: InvoiceDate e Quantity

# %% [markdown]
# ---

# %% [markdown]
# - **Tableau**
#
# Descrição: Reconhecida pela sua capacidade de visualização de dados avançada e interativa. É amplamente usada em ambientes corporativos e acadêmicos.

# %% [markdown]
# **Vantagens:**
# - Visualizações sofisticadas e personalizáveis.
# - Suporte para grandes volumes de dados.
# - Comunidade ativa e muitos recursos de aprendizado.
#
# Ideal para: Análise exploratória e apresentação visual impactante de dados.

# %% [markdown]
# ---

# %% [markdown]
# - **Google Data Studio**
#
# Descrição: Ferramenta gratuita do Google para criação de relatórios e dashboards interativos.

# %% [markdown]
# **Vantagens:**
#
# - Gratuito.
# - Integração nativa com outros produtos do Google (Analytics, Ads, BigQuery).
# - Fácil de compartilhar relatórios por links ou em tempo real.
#
# Ideal para: Pequenas e médias empresas que usam o Google Workspace ou plataformas de anúncios.

# %% [markdown]
# ---

# %% [markdown]
# - **Metabase**
#
# Descrição: Ferramenta de código aberto para geração de dashboards e relatórios, com foco na simplicidade.

# %% [markdown]
# **Vantagens:**
#
# - Gratuito e de código aberto.
# - Interface amigável para usuários não técnicos.
# - Ótima integração com bancos de dados SQL.
#
# Ideal para: Startups e pequenas empresas com equipes técnicas que preferem soluções de código aberto.

# %% [markdown]
# ---

# %% [markdown]
# ### 2.2 Dashboards com python Exemplo

# %%
pip install dash

# %% [markdown]
# Importamos as bibliotecas principais:
# - `Dash` para criar o dashboard interativo.
# - `dcc` e `html` para os componentes do layout.
# - `Input` e `Output` para criar callbacks interativos.
# - `plotly.express` para criar gráficos interativos.
# - `pandas` para manipulação de dados.

# %% [markdown]
# Usamos o dataset `gapminder` embutido no Plotly Express, que contém informações sobre países, como:
# - PIB per capita (`gdpPercap`)
# - Expectativa de vida (`lifeExp`)
# - População (`pop`)
# - Continente (`continent`)

# %% [markdown]
# # Informações sobre o Dataset `gapminder`
#
# O dataset `gapminder` é embutido no Plotly Express e contém dados sobre o desenvolvimento socioeconômico e demográfico de diferentes países em intervalos de cinco anos, de 1952 a 2007.
#
# ## Colunas e Descrições
#
# | **Coluna**        | **Descrição**                                                                 |
# |--------------------|-------------------------------------------------------------------------------|
# | `country`          | Nome do país.                                                               |
# | `continent`        | Continente ao qual o país pertence.                                         |
# | `year`             | Ano do dado registrado.                                                    |
# | `lifeExp`          | Expectativa de vida no país (em anos).                                      |
# | `pop`              | População total do país.                                                   |
# | `gdpPercap`        | PIB per capita do país (Produto Interno Bruto dividido pela população).     |
#
# ---
#
# ## Exemplo de Dados
#
# | **country** | **continent** | **year** | **lifeExp** | **pop**     | **gdpPercap** |
# |-------------|---------------|----------|-------------|-------------|---------------|
# | Afghanistan | Asia          | 1952     | 28.801      | 8425333     | 779.4453145   |
# | Brazil      | Americas      | 2007     | 72.390      | 190010647   | 9065.800825   |
# | Germany     | Europe        | 1997     | 77.725      | 82011073    | 25768.25759   |
#
# ---
#
# ## Principais Insights que o Dataset Permite
# 1. **Comparar Continentes:** Identificar diferenças de desenvolvimento econômico e social entre os continentes.
# 2. **Evolução Temporal:** Analisar como variáveis como expectativa de vida, população e PIB mudaram ao longo dos anos.
# 3. **Correlação de Dados:** Explorar a relação entre PIB per capita, população e expectativa de vida.

# %% [markdown]
# O layout é definido com os seguintes componentes:
# 1. **Título:** Um cabeçalho centralizado (`html.H1`).
# 2. **Dropdown:** Um menu suspenso para selecionar o continente (`dcc.Dropdown`).
# 3. **Gráfico:** Um espaço para exibir gráficos interativos (`dcc.Graph`).
# 4. **Texto Dinâmico:** Um espaço para mostrar informações extras.

# %% [markdown]
# O callback faz a conexão entre o dropdown e o gráfico:
# 1. **Entrada:** O valor selecionado no dropdown (`dropdown-continent`).
# 2. **Saídas:**
#    - Um gráfico de dispersão atualizado (`scatter-plot`).
#    - Texto mostrando o número de países no continente selecionado (`output-text`).
# 3. **Lógica:** Filtramos o dataset com base no continente e criamos um gráfico atualizado.

# %% [markdown]
# Para rodar o aplicativo, usamos:
# ```python
# if __name__ == '__main__':
#     app.run_server(debug=True)

# %% [markdown]
# Isso inicia o servidor local e exibe o dashboard no navegador.

# %%
# Importando as bibliotecas necessárias
from dash import Dash, dcc, html, Input, Output
import plotly.express as px
import pandas as pd

# Criando o aplicativo Dash
app = Dash(__name__)

# Criando um dataset para exibição
df = px.data.gapminder()  # Dataset embutido no Plotly

# Layout do aplicativo
app.layout = html.Div([
    html.H1("Dashboard Interativo: Dados de Países", style={'textAlign': 'center'}),
    dcc.Dropdown(
        id='dropdown-continent',
        options=[
            {'label': continente, 'value': continente}
            for continente in df['continent'].unique()
        ],
        value='Asia',  # Valor padrão
        clearable=False,
        style={'width': '50%', 'margin': '0 auto'}
    ),
    dcc.Graph(id='scatter-plot'),
    html.Div(id='output-text', style={'textAlign': 'center', 'marginTop': 20})
])

# Callback para atualizar o gráfico e o texto
@app.callback(
    [Output('scatter-plot', 'figure'),
     Output('output-text', 'children')],
    [Input('dropdown-continent', 'value')]
)
def update_dashboard(continente_selecionado):
    df_filtrado = df[df['continent'] == continente_selecionado]
    figura = px.scatter(
        df_filtrado,
        x='gdpPercap',
        y='lifeExp',
        color='country',
        size='pop',
        hover_name='country',
        title=f"Relação entre PIB e Expectativa de Vida ({continente_selecionado})",
        labels={
            'gdpPercap': 'PIB per capita',
            'lifeExp': 'Expectativa de Vida',
            'pop': 'População',
            'country': 'País'
        }
    )
    texto = f"Total de países exibidos: {df_filtrado['country'].nunique()}"
    return figura, texto

# Executando o aplicativo
if __name__ == '__main__':
    app.run_server(debug=True)

# %% [markdown]
# - iso_alpha: 	Código de três letras que representa o país, baseado no padrão ISO 3166-1 alpha-3 (ex.: BRA para Brasil).
# - iso_num: 	Código numérico de três dígitos que identifica o país, baseado no padrão ISO 3166-1 numeric.
